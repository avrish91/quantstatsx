# %%
# %matplotlib inline
import pandas as pd
import quantstats as qs

# %%
vip_levels = ['5','9']
core_pos_set = ['1','2half']

for (vip_level, core_pos) in [(vip_level, core_pos) for vip_level in vip_levels for core_pos in core_pos_set]:
    print(f"Processing VIP{vip_level} with {core_pos}M core position")
    df_1 = pd.read_parquet(f"C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part1.pqt")
    df_2 = pd.read_parquet(f"C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part2.pqt")
    df_3 = pd.read_parquet(f"C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part3.pqt")
    df_4 = pd.read_parquet(f"C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part4.pqt")
    df_5 = pd.read_parquet(f"C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part5.pqt")

    df = pd.concat([df_1, df_2, df_3, df_4, df_5])

    daily_df = df['wallet_balance'].resample('1D').last().dropna()
    perf_df = daily_df.pct_change().dropna()
    perf_df.index.names=['Date']
    qs.reports.html(perf_df, periods_per_year=365, compounded=False, output=f'C:/Users/User/Downloads/tearsheet_av_VIP{vip_level}_{core_pos}M_Spread_Notional.html')
    break
# Out:
# Processing VIP5 with 1M core position
# win_year 365
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:440: FutureWarning: The provided callable <function sum at 0x0000025D0C31DDA0> is currently using DatetimeIndexResampler.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   returns.fillna(0).resample(resample).apply(apply_fnc).resample(resample).last()
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:1015: FutureWarning: The provided callable <function sum at 0x0000025D0C31DDA0> is currently using DatetimeIndexResampler.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   port["Weekly"] = port["Daily"].resample("W-MON").apply(apply_fnc)
# ...

# %%
qs.reports.metrics_custom(perf_df, periods_per_year=365, compounded=False)
# Out:
# win_year 365
#                     Strategy
# ------------------  ----------
# Start Period        2023-09-03
# End Period          2025-01-31
# Time in Market      100.0%
#
# Total Return        14.52%
# CAGR﹪              6.84%
#
# Sharpe              4.4
# Prob. Sharpe Ratio  100.0%
# Sortino             8.2
#
# Max Drawdown        -1.41%
# Longest DD Days     106
#
# Gain/Pain Ratio     1.5
# Gain/Pain (1M)      35.42
# MTD                 2.15%
# 3M                  4.14%
# 6M                  5.94%
# YTD                 2.15%
# 1Y                  11.51%
# 3Y (ann.)           6.84%
# 5Y (ann.)           6.84%
# 10Y (ann.)          6.84%
# All-time (ann.)     6.84%
#
# Avg. Drawdown       -0.1%
# Avg. Drawdown Days  4
# Recovery Factor     10.33
# Ulcer Index         0.0
# Serenity Index      8.17

# %%
qs.reports.html_custom(perf_df, periods_per_year=365, compounded=False, output=f'C:/Users/User/Downloads/test.html')
# Out:
# win_year 365
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:440: FutureWarning: The provided callable <function sum at 0x0000025D0C31DDA0> is currently using DatetimeIndexResampler.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   returns.fillna(0).resample(resample).apply(apply_fnc).resample(resample).last()
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:1015: FutureWarning: The provided callable <function sum at 0x0000025D0C31DDA0> is currently using DatetimeIndexResampler.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   port["Weekly"] = port["Daily"].resample("W-MON").apply(apply_fnc)
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:1016: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
qs.reports.plots(perf_df, periods_per_year=365,compounded=False, mode = 'full')
# Out:
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:1016: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   port["Weekly"].ffill(inplace=True)
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:1019: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
qs.reports.plots(perf_df, periods_per_year=365,compounded=False, mode = 'full', templ)
# Out:
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:440: FutureWarning: The provided callable <function sum at 0x000001B636C3DDA0> is currently using DatetimeIndexResampler.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   returns.fillna(0).resample(resample).apply(apply_fnc).resample(resample).last()
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:1015: FutureWarning: The provided callable <function sum at 0x000001B636C3DDA0> is currently using DatetimeIndexResampler.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   port["Weekly"] = port["Daily"].resample("W-MON").apply(apply_fnc)
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:1016: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
qs.reports.

# %%
# Grab In Sample Spreader SIMs
vip_level = '9'
core_pos = '1'

df1 = pd.read_parquet(f'C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part1.pqt')
df2 = pd.read_parquet(f'C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part2.pqt')
df3 = pd.read_parquet(f'C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part3.pqt')
df4 = pd.read_parquet(f'C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part4.pqt')
df5 = pd.read_parquet(f'C:/Users/User/quantstatsx/agg_sim_{core_pos}M_6h_vip{vip_level}_part5.pqt')
df = pd.concat([df1,df2,df3,df4,df5])
df = df[['wallet_balance']]
# oos_df = pd.read_parquet('C:/Users/User/quantstatsx/oos_sim_variable_gmv_35_pov_nof.pqt')

# %%
df_resampled = df.resample('D').last()
df_resampled['daily_return'] = df_resampled['wallet_balance'].pct_change()
# agg_df_resampled.dropna(inplace = True) !!! Careful with that
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32304\4246206529.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_resampled['daily_return'] = df_resampled['wallet_balance'].pct_change()

# %%
df_resampled = df_resampled[['wallet_balance', 'daily_return']]
df_resampled.dropna(inplace = True)

# %%
df_resampled.index.names = ['Date']

# %%
# (benchmark can be a pandas Series or ticker)
# fetch the daily returns for a stock
# stock = qs.utils.download_returns('PLTR')
qs.reports.html(df_resampled['daily_return']*5, periods_per_year = 365, compounded = False, output='C:/Users/User/Downloads/alpha3.html')
# Out:
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:440: FutureWarning: The provided callable <function sum at 0x000001E2B4DDDDA0> is currently using DatetimeIndexResampler.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   returns.fillna(0).resample(resample).apply(apply_fnc).resample(resample).last()
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:1015: FutureWarning: The provided callable <function sum at 0x000001E2B4DDDDA0> is currently using DatetimeIndexResampler.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   port["Weekly"] = port["Daily"].resample("W-MON").apply(apply_fnc)
# C:\Users\User\quantstatsx\quantstats\_plotting\core.py:1016: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\quantstatsx'

# %%
C:\Users\User\Downloads
